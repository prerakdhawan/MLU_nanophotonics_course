# %% [markdown]
# # Transmittance Spectra for Planewave at Normal Incidence of a Binary Grating

# %% [markdown]
# The mode-decomposition feature can also be applied to planewaves in homogeneous media with scalar permittivity/permeability (i.e., no anisotropy). This will be demonstrated in this example to compute the diffraction spectrum of a binary phase [grating](https://en.wikipedia.org/wiki/Diffraction_grating). To compute the diffraction spectrum for a finite-length structure, see [Tutorials/Near to Far Field Spectra/Diffraction Spectrum of a Finite Binary Grating](https://meep.readthedocs.io/en/latest/Python_Tutorials/Near_to_Far_Field_Spectra/#diffraction-spectrum-of-a-finite-binary-grating).
#
# In this example, we'll define a grating that is periodic in the $y$ direction with periodicity `gp` and has a rectangular profile of height `gh` and duty cycle `gdc`. The grating parameters are `gh`=0.5 μm, `gdc`=0.5, and `gp`=10 μm. There is a semi-infinite substrate of thickness `dsub` adjacent to the grating. The substrate and grating are glass with a refractive index of 1.5. The surrounding is air/vacuum. Perfectly matched layers (PML) of thickness `dpml` are used in the $\pm x$ boundaries.
#
# We'll do our analysis first using an ideal quartz that ignores the dispersion of the material. Then we'll include the dispersion to detect any differences.
#
# A pulsed planewave with $E_z$ polarization spanning wavelengths of 0.4 to 0.6 μm is normally incident on the grating from the glass substrate. The eigenmode monitor is placed in the air region. We will use mode decomposition to compute the transmittance — the ratio of the power in the $+x$ direction of the diffracted mode relative to that of the incident planewave — for the first ten diffraction orders.
#
# Two simulations are required: (1) an empty cell of homogeneous glass to obtain the incident power of the source, and (2) the grating structure to obtain the diffraction orders. At the end of the simulation, the wavelength, angle, and transmittance for each diffraction order are computed.
#
# Initially, we'll import our standard libraries:

# %%
import meep as mp
import math
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using MPI version 4.1, 1 processes

# %% [markdown]
# We first need to simulate the empty, homogenous glass (fuzed quartz) with a constant refractive index.

# %%
fused_quartz = mp.Medium(index=1.5)

resolution = 50  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 3.0  # substrate thickness
dpad = 3.0  # padding between grating and PML
gp = 10.0  # grating period
gh = 0.5  # grating height
gdc = 0.5  # grating duty cycle

sx = dpml + dsub + gh + dpad + dpml
sy = gp

cell_size = mp.Vector3(sx, sy, 0)
pml_layers = [mp.PML(thickness=dpml, direction=mp.X)]

wvl_min = 0.4  # min wavelength
wvl_max = 0.6  # max wavelength
fmin = 1 / wvl_max  # min frequency
fmax = 1 / wvl_min  # max frequency
fcen = 0.5 * (fmin + fmax)  # center frequency
df = fmax - fmin  # frequency width

src_pt = mp.Vector3(-0.5 * sx + dpml + 0.5 * dsub)
sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df),
        component=mp.Ez,
        center=src_pt,
        size=mp.Vector3(y=sy),
    )
]

k_point = mp.Vector3(0, 0, 0)

symmetries = [mp.Mirror(mp.Y)]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    k_point=k_point,
    default_material=fused_quartz,
    sources=sources,
    symmetries=symmetries,
)

nfreq = 21
mon_pt = mp.Vector3(0.5 * sx - dpml - 0.5 * dpad)
flux_mon = sim.add_flux(
    fcen, df, nfreq, mp.FluxRegion(center=mon_pt, size=mp.Vector3(y=sy))
)

f = plt.figure(dpi=120)
sim.plot2D(ax=f.gca())
plt.show()

# %% [markdown]
# Now, we'll run the simulation and record the fields.

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mon_pt, 1e-9))
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00167485 s
# Working in 2D dimensions.
# Computational cell is 8.5 x 10 x 0 with resolution 50
# time for set_epsilon = 0.234603 s
# -----------
# field decay(t = 50.01): 0.10609306658233122 / 0.10609306658233122 = 1.0
# on time step 7400 (time=74), 0.000540591 s/step
# field decay(t = 100.01): 8.49320047476421e-20 / 0.10609306658233122 = 8.005424622327459e-19
# run 0 finished at t = 100.01 (10001 timesteps)

# %%
input_flux = mp.get_fluxes(flux_mon)

# %% [markdown]
# Next, we'll simulate the actual grating.

# %%
sim.reset_meep()

geometry = [
    mp.Block(
        material=fused_quartz,
        size=mp.Vector3(dpml + dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + 0.5 * (dpml + dsub)),
    ),
    mp.Block(
        material=fused_quartz,
        size=mp.Vector3(gh, gdc * gp, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + dsub + 0.5 * gh),
    ),
]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    k_point=k_point,
    sources=sources,
    symmetries=symmetries,
)

mode_mon = sim.add_flux(
    fcen, df, nfreq, mp.FluxRegion(center=mon_pt, size=mp.Vector3(y=sy))
)

f2 = plt.figure(dpi=120)
sim.plot2D(ax=f2.gca())
plt.show()
# Out:
#      block, center = (-2.25,0,0)
#           size (4,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (0,0,0)
#           size (0.5,5,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mon_pt, 1e-6))
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00256666 s
# Working in 2D dimensions.
# Computational cell is 8.5 x 10 x 0 with resolution 50
#      block, center = (-2.25,0,0)
#           size (4,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (0,0,0)
#           size (0.5,5,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.312583 s
# -----------
# field decay(t = 50.01): 0.10313983413160129 / 0.10313983413160129 = 1.0
# on time step 6324 (time=63.24), 0.000632516 s/step
# field decay(t = 100.01): 8.722717573234794e-06 / 0.10313983413160129 = 8.457176266257167e-05
# on time step 13653 (time=136.53), 0.000545796 s/step
# field decay(t = 150.02): 8.334419117799765e-06 / 0.10313983413160129 = 8.080698585539184e-05
# field decay(t = 200.03): 2.8882043261523054e-06 / 0.10313983413160129 = 2.800280173484767e-05
# on time step 21357 (time=213.57), 0.000519245 s/step
# field decay(t = 250.04): 1.2213514092598078e-06 / 0.10313983413160129 = 1.1841704221682422e-05
# on time step 28871 (time=288.71), 0.000532374 s/step
# field decay(t = 300.04): 4.961700132424876e-07 / 0.10313983413160129 = 4.810653589081784e-06
# field decay(t = 350.05): 2.181180260115915e-07 / 0.10313983413160129 = 2.114779685735036e-06
# on time step 36366 (time=363.66), 0.000533721 s/step
# field decay(t = 400.06): 9.238523656598188e-08 / 0.10313983413160129 = 8.957279924272801e-07
# on time step 43981 (time=439.81), 0.000525309 s/step
# field decay(t = 450.07): 3.8547093555694874e-08 / 0.10313983413160129 = 3.737362376064199e-07
# field decay(t = 500.08): 1.6071097361484466e-08 / 0.10313983413160129 = 1.5581853021964866e-07
# on time step 51582 (time=515.82), 0.000526294 s/step
# field decay(t = 550.08): 6.924227749169196e-09 / 0.10313983413160129 = 6.713436963970901e-08
# on time step 58828 (time=588.28), 0.000552126 s/step
# field decay(t = 600.09): 3.2583647314614707e-09 / 0.10313983413160129 = 3.1591719716205475e-08
# field decay(t = 650.1): 1.6219547887218161e-09 / 0.10313983413160129 = 1.5725784342956016e-08
# on time step 65940 (time=659.4), 0.000562479 s/step
# field decay(t = 700.11): 5.911302870130849e-10 / 0.10313983413160129 = 5.73134804792135e-09
# on time step 73910 (time=739.1), 0.000501904 s/step
# field decay(t = 750.12): 2.2873955002805154e-10 / 0.10313983413160129 = 2.217761468727895e-09
# field decay(t = 800.13): 1.1438721121486005e-10 / 0.10313983413160129 = 1.109049788357306e-09
# on time step 81745 (time=817.45), 0.000510588 s/step
# field decay(t = 850.14): 6.942745342894243e-11 / 0.10313983413160129 = 6.731390835897259e-10
# run 0 finished at t = 850.14 (85014 timesteps)

# %% [markdown]
# Now we can compute the diffraction orders as a function of wavelength:

# %%
freqs = mp.get_eigenmode_freqs(mode_mon)

nmode = 10
res = sim.get_eigenmode_coefficients(
    mode_mon, range(1, nmode + 1), eig_parity=mp.ODD_Z + mp.EVEN_Y
)
coeffs = res.alpha
kdom = res.kdom

mode_wvl = []
mode_angle = []
mode_tran = []

for nm in range(nmode):
    for nf in range(nfreq):
        mode_wvl.append(1 / freqs[nf])
        mode_angle.append(math.degrees(math.acos(kdom[nm * nfreq + nf].x / freqs[nf])))
        tran = abs(coeffs[nm, nf, 0]) ** 2 / input_flux[nf]
        mode_tran.append(0.5 * tran if nm != 0 else tran)

tran_max = round(max(mode_tran), 1)
# Out:
# MPB solved for frequency_1(1.66667,0,0) = 1.66667 after 66 iters
# Dominant planewave for band 1: (1.666667,-0.000000,0.000000)
# MPB solved for frequency_1(1.70833,0,0) = 1.70833 after 68 iters
# Dominant planewave for band 1: (1.708333,-0.000000,0.000000)
# MPB solved for frequency_1(1.75,0,0) = 1.75 after 69 iters
# Dominant planewave for band 1: (1.750000,-0.000000,0.000000)
# MPB solved for frequency_1(1.79167,0,0) = 1.79167 after 70 iters
# Dominant planewave for band 1: (1.791667,-0.000000,0.000000)
# MPB solved for frequency_1(1.83333,0,0) = 1.83333 after 72 iters
# Dominant planewave for band 1: (1.833333,-0.000000,0.000000)
# MPB solved for frequency_1(1.875,0,0) = 1.875 after 76 iters
# Dominant planewave for band 1: (1.875000,-0.000000,0.000000)
# MPB solved for frequency_1(1.91667,0,0) = 1.91667 after 78 iters
# Dominant planewave for band 1: (1.916667,-0.000000,0.000000)
# MPB solved for frequency_1(1.95833,0,0) = 1.95833 after 80 iters
# Dominant planewave for band 1: (1.958333,-0.000000,0.000000)
# MPB solved for frequency_1(2,0,0) = 2 after 83 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# MPB solved for frequency_1(2.04167,0,0) = 2.04167 after 85 iters
# Dominant planewave for band 1: (2.041667,-0.000000,0.000000)
# MPB solved for frequency_1(2.08333,0,0) = 2.08333 after 95 iters
# Dominant planewave for band 1: (2.083333,-0.000000,0.000000)
# MPB solved for frequency_1(2.125,0,0) = 2.125 after 98 iters
# Dominant planewave for band 1: (2.125000,-0.000000,0.000000)
# MPB solved for frequency_1(2.16667,0,0) = 2.16667 after 94 iters
# Dominant planewave for band 1: (2.166667,-0.000000,0.000000)
# MPB solved for frequency_1(2.20833,0,0) = 2.20833 after 96 iters
# Dominant planewave for band 1: (2.208333,-0.000000,0.000000)
# MPB solved for frequency_1(2.25,0,0) = 2.25 after 93 iters
# Dominant planewave for band 1: (2.250000,-0.000000,0.000000)
# MPB solved for frequency_1(2.29167,0,0) = 2.29167 after 94 iters
# Dominant planewave for band 1: (2.291667,-0.000000,0.000000)
# MPB solved for frequency_1(2.33333,0,0) = 2.33333 after 90 iters
# Dominant planewave for band 1: (2.333333,-0.000000,0.000000)
# MPB solved for frequency_1(2.375,0,0) = 2.375 after 91 iters
# Dominant planewave for band 1: (2.375000,-0.000000,0.000000)
# MPB solved for frequency_1(2.41667,0,0) = 2.41667 after 91 iters
# Dominant planewave for band 1: (2.416667,-0.000000,0.000000)
# MPB solved for frequency_1(2.45833,0,0) = 2.45833 after 93 iters
# Dominant planewave for band 1: (2.458333,-0.000000,0.000000)
# MPB solved for frequency_1(2.5,0,0) = 2.5 after 95 iters
# Dominant planewave for band 1: (2.500000,-0.000000,0.000000)
# MPB solved for frequency_2(2.5,0,0) = 2.502 after 95 iters
# MPB solved for frequency_2(1.664,0,0) = 1.667 after 1 iters
# MPB solved for frequency_2(1.66366,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_2(1.66366,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 2: (1.663664,-0.100000,0.000000)
# MPB solved for frequency_2(1.70541,0,0) = 1.70834 after 65 iters
# MPB solved for frequency_2(1.7054,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 2: (1.705404,-0.100000,0.000000)
# MPB solved for frequency_2(1.74714,0,0) = 1.75 after 66 iters
# MPB solved for frequency_2(1.74714,0,0) = 1.75 after 1 iters
# Dominant planewave for band 2: (1.747141,-0.100000,0.000000)
# MPB solved for frequency_2(1.78888,0,0) = 1.79167 after 68 iters
# MPB solved for frequency_2(1.78887,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 2: (1.788874,-0.100000,0.000000)
# MPB solved for frequency_2(1.83061,0,0) = 1.83333 after 69 iters
# MPB solved for frequency_2(1.8306,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 2: (1.830604,-0.100000,0.000000)
# MPB solved for frequency_2(1.87233,0,0) = 1.875 after 70 iters
# MPB solved for frequency_2(1.87233,0,0) = 1.875 after 1 iters
# Dominant planewave for band 2: (1.872331,-0.100000,0.000000)
# MPB solved for frequency_2(1.91406,0,0) = 1.91667 after 70 iters
# MPB solved for frequency_2(1.91406,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 2: (1.914056,-0.100000,0.000000)
# MPB solved for frequency_2(1.95578,0,0) = 1.95833 after 74 iters
# MPB solved for frequency_2(1.95578,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 2: (1.955778,-0.100000,0.000000)
# MPB solved for frequency_2(1.9975,0,0) = 2 after 76 iters
# MPB solved for frequency_2(1.9975,0,0) = 2 after 1 iters
# Dominant planewave for band 2: (1.997498,-0.100000,0.000000)
# MPB solved for frequency_2(2.03922,0,0) = 2.04167 after 77 iters
# MPB solved for frequency_2(2.03922,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 2: (2.039216,-0.100000,0.000000)
# MPB solved for frequency_2(2.08093,0,0) = 2.08333 after 78 iters
# MPB solved for frequency_2(2.08093,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 2: (2.080932,-0.100000,0.000000)
# MPB solved for frequency_2(2.12265,0,0) = 2.125 after 82 iters
# MPB solved for frequency_2(2.12265,0,0) = 2.125 after 1 iters
# Dominant planewave for band 2: (2.122646,-0.100000,0.000000)
# MPB solved for frequency_2(2.16436,0,0) = 2.16667 after 87 iters
# MPB solved for frequency_2(2.16436,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 2: (2.164358,-0.100000,0.000000)
# MPB solved for frequency_2(2.20607,0,0) = 2.20833 after 88 iters
# MPB solved for frequency_2(2.20607,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 2: (2.206068,-0.100000,0.000000)
# MPB solved for frequency_2(2.24778,0,0) = 2.25 after 89 iters
# MPB solved for frequency_2(2.24778,0,0) = 2.25 after 1 iters
# Dominant planewave for band 2: (2.247777,-0.100000,0.000000)
# MPB solved for frequency_2(2.28948,0,0) = 2.29167 after 89 iters
# MPB solved for frequency_2(2.28948,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 2: (2.289484,-0.100000,0.000000)
# MPB solved for frequency_2(2.33119,0,0) = 2.33333 after 90 iters
# MPB solved for frequency_2(2.33119,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 2: (2.331189,-0.100000,0.000000)
# MPB solved for frequency_2(2.37289,0,0) = 2.375 after 91 iters
# MPB solved for frequency_2(2.37289,0,0) = 2.375 after 1 iters
# Dominant planewave for band 2: (2.372894,-0.100000,0.000000)
# MPB solved for frequency_2(2.4146,0,0) = 2.41667 after 93 iters
# MPB solved for frequency_2(2.4146,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 2: (2.414597,-0.100000,0.000000)
# MPB solved for frequency_2(2.4563,0,0) = 2.45833 after 94 iters
# MPB solved for frequency_2(2.4563,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 2: (2.456299,-0.100000,0.000000)
# MPB solved for frequency_2(2.498,0,0) = 2.5 after 94 iters
# MPB solved for frequency_2(2.498,0,0) = 2.5 after 1 iters
# Dominant planewave for band 2: (2.497999,-0.100000,0.000000)
# MPB solved for frequency_3(2.498,0,0) = 2.50599 after 69 iters
# MPB solved for frequency_3(1.65599,0,0) = 1.66802 after 4 iters
# MPB solved for frequency_3(1.65462,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_3(1.65462,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 3: (1.654623,-0.200000,0.000000)
# MPB solved for frequency_3(1.69659,0,0) = 1.70834 after 50 iters
# MPB solved for frequency_3(1.69659,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 3: (1.696586,-0.200000,0.000000)
# MPB solved for frequency_3(1.73854,0,0) = 1.75001 after 51 iters
# MPB solved for frequency_3(1.73853,0,0) = 1.75 after 1 iters
# Dominant planewave for band 3: (1.738534,-0.200000,0.000000)
# MPB solved for frequency_3(1.78048,0,0) = 1.79167 after 52 iters
# MPB solved for frequency_3(1.78047,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 3: (1.780469,-0.200000,0.000000)
# MPB solved for frequency_3(1.8224,0,0) = 1.83334 after 53 iters
# MPB solved for frequency_3(1.82239,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 3: (1.822392,-0.200000,0.000000)
# MPB solved for frequency_3(1.86431,0,0) = 1.87501 after 54 iters
# MPB solved for frequency_3(1.8643,0,0) = 1.875 after 1 iters
# Dominant planewave for band 3: (1.864303,-0.200000,0.000000)
# MPB solved for frequency_3(1.90621,0,0) = 1.91667 after 55 iters
# MPB solved for frequency_3(1.9062,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 3: (1.906203,-0.200000,0.000000)
# MPB solved for frequency_3(1.9481,0,0) = 1.95834 after 56 iters
# MPB solved for frequency_3(1.94809,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 3: (1.948094,-0.200000,0.000000)
# MPB solved for frequency_3(1.98998,0,0) = 2 after 57 iters
# MPB solved for frequency_3(1.98997,0,0) = 2 after 1 iters
# Dominant planewave for band 3: (1.989975,-0.200000,0.000000)
# MPB solved for frequency_3(2.03185,0,0) = 2.04167 after 58 iters
# MPB solved for frequency_3(2.03185,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 3: (2.031847,-0.200000,0.000000)
# MPB solved for frequency_3(2.07372,0,0) = 2.08334 after 59 iters
# MPB solved for frequency_3(2.07371,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 3: (2.073711,-0.200000,0.000000)
# MPB solved for frequency_3(2.11557,0,0) = 2.125 after 61 iters
# MPB solved for frequency_3(2.11557,0,0) = 2.125 after 1 iters
# Dominant planewave for band 3: (2.115567,-0.200000,0.000000)
# MPB solved for frequency_3(2.15742,0,0) = 2.16667 after 62 iters
# MPB solved for frequency_3(2.15742,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 3: (2.157416,-0.200000,0.000000)
# MPB solved for frequency_3(2.19926,0,0) = 2.20834 after 62 iters
# MPB solved for frequency_3(2.19926,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 3: (2.199258,-0.200000,0.000000)
# MPB solved for frequency_3(2.2411,0,0) = 2.25 after 63 iters
# MPB solved for frequency_3(2.24109,0,0) = 2.25 after 1 iters
# Dominant planewave for band 3: (2.241093,-0.200000,0.000000)
# MPB solved for frequency_3(2.28293,0,0) = 2.29167 after 64 iters
# MPB solved for frequency_3(2.28292,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 3: (2.282923,-0.200000,0.000000)
# MPB solved for frequency_3(2.32475,0,0) = 2.33334 after 65 iters
# MPB solved for frequency_3(2.32475,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 3: (2.324746,-0.200000,0.000000)
# MPB solved for frequency_3(2.36657,0,0) = 2.375 after 66 iters
# MPB solved for frequency_3(2.36656,0,0) = 2.375 after 1 iters
# Dominant planewave for band 3: (2.366564,-0.200000,0.000000)
# MPB solved for frequency_3(2.40838,0,0) = 2.41667 after 67 iters
# MPB solved for frequency_3(2.40838,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 3: (2.408377,-0.200000,0.000000)
# MPB solved for frequency_3(2.45019,0,0) = 2.45834 after 68 iters
# MPB solved for frequency_3(2.45018,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 3: (2.450184,-0.200000,0.000000)
# MPB solved for frequency_3(2.49199,0,0) = 2.5 after 69 iters
# MPB solved for frequency_3(2.49199,0,0) = 2.5 after 1 iters
# Dominant planewave for band 3: (2.491987,-0.200000,0.000000)
# MPB solved for frequency_4(2.49199,0,0) = 2.50998 after 62 iters
# MPB solved for frequency_4(1.64258,0,0) = 1.66976 after 1 iters
# MPB solved for frequency_4(1.63944,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_4(1.63944,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 4: (1.639444,-0.300000,0.000000)
# MPB solved for frequency_4(1.6818,0,0) = 1.70835 after 44 iters
# MPB solved for frequency_4(1.68179,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 4: (1.681786,-0.300000,0.000000)
# MPB solved for frequency_4(1.72411,0,0) = 1.75002 after 45 iters
# MPB solved for frequency_4(1.72409,0,0) = 1.75 after 1 iters
# Dominant planewave for band 4: (1.724094,-0.300000,0.000000)
# MPB solved for frequency_4(1.76639,0,0) = 1.79168 after 46 iters
# MPB solved for frequency_4(1.76637,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 4: (1.766372,-0.300000,0.000000)
# MPB solved for frequency_4(1.80864,0,0) = 1.83335 after 47 iters
# MPB solved for frequency_4(1.80862,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 4: (1.808621,-0.300000,0.000000)
# MPB solved for frequency_4(1.85086,0,0) = 1.87501 after 48 iters
# MPB solved for frequency_4(1.85084,0,0) = 1.875 after 1 iters
# Dominant planewave for band 4: (1.850844,-0.300000,0.000000)
# MPB solved for frequency_4(1.89305,0,0) = 1.91668 after 48 iters
# MPB solved for frequency_4(1.89304,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 4: (1.893043,-0.300000,0.000000)
# MPB solved for frequency_4(1.93523,0,0) = 1.95834 after 49 iters
# MPB solved for frequency_4(1.93522,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 4: (1.935218,-0.300000,0.000000)
# MPB solved for frequency_4(1.97738,0,0) = 2.00001 after 50 iters
# MPB solved for frequency_4(1.97737,0,0) = 2 after 1 iters
# Dominant planewave for band 4: (1.977372,-0.300000,0.000000)
# MPB solved for frequency_4(2.01952,0,0) = 2.04168 after 51 iters
# MPB solved for frequency_4(2.01951,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 4: (2.019506,-0.300000,0.000000)
# MPB solved for frequency_4(2.06163,0,0) = 2.08334 after 52 iters
# MPB solved for frequency_4(2.06162,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 4: (2.061620,-0.300000,0.000000)
# MPB solved for frequency_4(2.10373,0,0) = 2.12501 after 53 iters
# MPB solved for frequency_4(2.10372,0,0) = 2.125 after 1 iters
# Dominant planewave for band 4: (2.103717,-0.300000,0.000000)
# MPB solved for frequency_4(2.14581,0,0) = 2.16667 after 54 iters
# MPB solved for frequency_4(2.1458,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 4: (2.145797,-0.300000,0.000000)
# MPB solved for frequency_4(2.18787,0,0) = 2.20834 after 55 iters
# MPB solved for frequency_4(2.18786,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 4: (2.187861,-0.300000,0.000000)
# MPB solved for frequency_4(2.22992,0,0) = 2.25001 after 56 iters
# MPB solved for frequency_4(2.22991,0,0) = 2.25 after 1 iters
# Dominant planewave for band 4: (2.229910,-0.300000,0.000000)
# MPB solved for frequency_4(2.27195,0,0) = 2.29167 after 57 iters
# MPB solved for frequency_4(2.27195,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 4: (2.271945,-0.300000,0.000000)
# MPB solved for frequency_4(2.31397,0,0) = 2.33334 after 58 iters
# MPB solved for frequency_4(2.31397,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 4: (2.313967,-0.300000,0.000000)
# MPB solved for frequency_4(2.35598,0,0) = 2.37501 after 59 iters
# MPB solved for frequency_4(2.35598,0,0) = 2.375 after 1 iters
# Dominant planewave for band 4: (2.355976,-0.300000,0.000000)
# MPB solved for frequency_4(2.39798,0,0) = 2.41667 after 60 iters
# MPB solved for frequency_4(2.39797,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 4: (2.397974,-0.300000,0.000000)
# MPB solved for frequency_4(2.43997,0,0) = 2.45834 after 60 iters
# MPB solved for frequency_4(2.43996,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 4: (2.439960,-0.300000,0.000000)
# MPB solved for frequency_4(2.48194,0,0) = 2.50001 after 61 iters
# MPB solved for frequency_4(2.48193,0,0) = 2.5 after 1 iters
# Dominant planewave for band 4: (2.481935,-0.300000,0.000000)
# MPB solved for frequency_5(2.48194,0,0) = 2.51397 after 57 iters
# MPB solved for frequency_5(1.62371,0,0) = 1.67225 after 1 iters
# MPB solved for frequency_5(1.61796,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_5(1.61795,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 5: (1.617955,-0.400000,0.000000)
# MPB solved for frequency_5(1.66088,0,0) = 1.70836 after 40 iters
# MPB solved for frequency_5(1.66084,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 5: (1.660844,-0.400000,0.000000)
# MPB solved for frequency_5(1.7037,0,0) = 1.75003 after 38 iters
# MPB solved for frequency_5(1.70367,0,0) = 1.75 after 1 iters
# Dominant planewave for band 5: (1.703673,-0.400000,0.000000)
# MPB solved for frequency_5(1.74647,0,0) = 1.79169 after 42 iters
# MPB solved for frequency_5(1.74644,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 5: (1.746445,-0.400000,0.000000)
# MPB solved for frequency_5(1.78919,0,0) = 1.83336 after 47 iters
# MPB solved for frequency_5(1.78916,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 5: (1.789165,-0.400000,0.000000)
# MPB solved for frequency_5(1.83186,0,0) = 1.87502 after 44 iters
# MPB solved for frequency_5(1.83184,0,0) = 1.875 after 1 iters
# Dominant planewave for band 5: (1.831837,-0.400000,0.000000)
# MPB solved for frequency_5(1.87448,0,0) = 1.91669 after 45 iters
# MPB solved for frequency_5(1.87446,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 5: (1.874463,-0.400000,0.000000)
# MPB solved for frequency_5(1.91707,0,0) = 1.95835 after 45 iters
# MPB solved for frequency_5(1.91705,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 5: (1.917047,-0.400000,0.000000)
# MPB solved for frequency_5(1.95961,0,0) = 2.00002 after 46 iters
# MPB solved for frequency_5(1.95959,0,0) = 2 after 1 iters
# Dominant planewave for band 5: (1.959592,-0.400000,0.000000)
# MPB solved for frequency_5(2.00212,0,0) = 2.04168 after 47 iters
# MPB solved for frequency_5(2.0021,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 5: (2.002100,-0.400000,0.000000)
# MPB solved for frequency_5(2.04459,0,0) = 2.08335 after 48 iters
# MPB solved for frequency_5(2.04457,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 5: (2.044573,-0.400000,0.000000)
# MPB solved for frequency_5(2.08703,0,0) = 2.12502 after 49 iters
# MPB solved for frequency_5(2.08701,0,0) = 2.125 after 1 iters
# Dominant planewave for band 5: (2.087013,-0.400000,0.000000)
# MPB solved for frequency_5(2.12944,0,0) = 2.16668 after 50 iters
# MPB solved for frequency_5(2.12942,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 5: (2.129424,-0.400000,0.000000)
# MPB solved for frequency_5(2.17182,0,0) = 2.20835 after 51 iters
# MPB solved for frequency_5(2.1718,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 5: (2.171805,-0.400000,0.000000)
# MPB solved for frequency_5(2.21417,0,0) = 2.25001 after 51 iters
# MPB solved for frequency_5(2.21416,0,0) = 2.25 after 1 iters
# Dominant planewave for band 5: (2.214159,-0.400000,0.000000)
# MPB solved for frequency_5(2.2565,0,0) = 2.29168 after 52 iters
# MPB solved for frequency_5(2.25649,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 5: (2.256488,-0.400000,0.000000)
# MPB solved for frequency_5(2.2988,0,0) = 2.33335 after 53 iters
# MPB solved for frequency_5(2.29879,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 5: (2.298792,-0.400000,0.000000)
# MPB solved for frequency_5(2.34108,0,0) = 2.37501 after 54 iters
# MPB solved for frequency_5(2.34107,0,0) = 2.375 after 1 iters
# Dominant planewave for band 5: (2.341073,-0.400000,0.000000)
# MPB solved for frequency_5(2.38334,0,0) = 2.41668 after 51 iters
# MPB solved for frequency_5(2.38333,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 5: (2.383333,-0.400000,0.000000)
# MPB solved for frequency_5(2.42558,0,0) = 2.45834 after 56 iters
# MPB solved for frequency_5(2.42557,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 5: (2.425573,-0.400000,0.000000)
# MPB solved for frequency_5(2.4678,0,0) = 2.50001 after 56 iters
# MPB solved for frequency_5(2.46779,0,0) = 2.5 after 1 iters
# Dominant planewave for band 5: (2.467793,-0.400000,0.000000)
# MPB solved for frequency_6(2.4678,0,0) = 2.51795 after 48 iters
# MPB solved for frequency_6(1.59923,0,0) = 1.67557 after 2 iters
# MPB solved for frequency_6(1.5899,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_6(1.5899,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 6: (1.589899,-0.500000,0.000000)
# MPB solved for frequency_6(1.63358,0,0) = 1.70838 after 34 iters
# MPB solved for frequency_6(1.63352,0,0) = 1.70833 after 1 iters
# MPB solved for frequency_6(1.63352,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 6: (1.633525,-0.500000,0.000000)
# MPB solved for frequency_6(1.6771,0,0) = 1.75005 after 34 iters
# MPB solved for frequency_6(1.67705,0,0) = 1.75 after 1 iters
# MPB solved for frequency_6(1.67705,0,0) = 1.75 after 1 iters
# Dominant planewave for band 6: (1.677051,-0.500000,0.000000)
# MPB solved for frequency_6(1.72053,0,0) = 1.79171 after 35 iters
# MPB solved for frequency_6(1.72049,0,0) = 1.79167 after 1 iters
# MPB solved for frequency_6(1.72049,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 6: (1.720485,-0.500000,0.000000)
# MPB solved for frequency_6(1.76388,0,0) = 1.83337 after 36 iters
# MPB solved for frequency_6(1.76383,0,0) = 1.83333 after 1 iters
# MPB solved for frequency_6(1.76383,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 6: (1.763834,-0.500000,0.000000)
# MPB solved for frequency_6(1.80714,0,0) = 1.87504 after 36 iters
# MPB solved for frequency_6(1.8071,0,0) = 1.875 after 1 iters
# MPB solved for frequency_6(1.8071,0,0) = 1.875 after 1 iters
# Dominant planewave for band 6: (1.807104,-0.500000,0.000000)
# MPB solved for frequency_6(1.85034,0,0) = 1.9167 after 37 iters
# MPB solved for frequency_6(1.8503,0,0) = 1.91667 after 1 iters
# MPB solved for frequency_6(1.8503,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 6: (1.850300,-0.500000,0.000000)
# MPB solved for frequency_6(1.89346,0,0) = 1.95837 after 39 iters
# MPB solved for frequency_6(1.89343,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 6: (1.893428,-0.500000,0.000000)
# MPB solved for frequency_6(1.93652,0,0) = 2.00003 after 38 iters
# MPB solved for frequency_6(1.93649,0,0) = 2 after 1 iters
# Dominant planewave for band 6: (1.936492,-0.500000,0.000000)
# MPB solved for frequency_6(1.97952,0,0) = 2.0417 after 38 iters
# MPB solved for frequency_6(1.9795,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 6: (1.979496,-0.500000,0.000000)
# MPB solved for frequency_6(2.02247,0,0) = 2.08336 after 40 iters
# MPB solved for frequency_6(2.02244,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 6: (2.022444,-0.500000,0.000000)
# MPB solved for frequency_6(2.06536,0,0) = 2.12502 after 42 iters
# MPB solved for frequency_6(2.06534,0,0) = 2.125 after 1 iters
# Dominant planewave for band 6: (2.065339,-0.500000,0.000000)
# MPB solved for frequency_6(2.10821,0,0) = 2.16669 after 42 iters
# MPB solved for frequency_6(2.10819,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 6: (2.108185,-0.500000,0.000000)
# MPB solved for frequency_6(2.15101,0,0) = 2.20836 after 43 iters
# MPB solved for frequency_6(2.15098,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 6: (2.150985,-0.500000,0.000000)
# MPB solved for frequency_6(2.19376,0,0) = 2.25002 after 43 iters
# MPB solved for frequency_6(2.19374,0,0) = 2.25 after 1 iters
# Dominant planewave for band 6: (2.193741,-0.500000,0.000000)
# MPB solved for frequency_6(2.23648,0,0) = 2.29169 after 43 iters
# MPB solved for frequency_6(2.23646,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 6: (2.236456,-0.500000,0.000000)
# MPB solved for frequency_6(2.27915,0,0) = 2.33335 after 44 iters
# MPB solved for frequency_6(2.27913,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 6: (2.279132,-0.500000,0.000000)
# MPB solved for frequency_6(2.32179,0,0) = 2.37502 after 46 iters
# MPB solved for frequency_6(2.32177,0,0) = 2.375 after 1 iters
# Dominant planewave for band 6: (2.321772,-0.500000,0.000000)
# MPB solved for frequency_6(2.36439,0,0) = 2.41668 after 44 iters
# MPB solved for frequency_6(2.36438,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 6: (2.364377,-0.500000,0.000000)
# MPB solved for frequency_6(2.40696,0,0) = 2.45835 after 45 iters
# MPB solved for frequency_6(2.40695,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 6: (2.406949,-0.500000,0.000000)
# MPB solved for frequency_6(2.44951,0,0) = 2.50001 after 48 iters
# MPB solved for frequency_6(2.44949,0,0) = 2.5 after 1 iters
# Dominant planewave for band 6: (2.449490,-0.500000,0.000000)
# MPB solved for frequency_7(2.44951,0,0) = 2.52192 after 46 iters
# MPB solved for frequency_7(1.56897,0,0) = 1.67978 after 1 iters
# MPB solved for frequency_7(1.55493,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_7(1.55492,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 7: (1.554921,-0.600000,0.000000)
# MPB solved for frequency_7(1.59958,0,0) = 1.70841 after 30 iters
# MPB solved for frequency_7(1.5995,0,0) = 1.70833 after 1 iters
# MPB solved for frequency_7(1.5995,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 7: (1.599501,-0.600000,0.000000)
# MPB solved for frequency_7(1.644,0,0) = 1.75007 after 31 iters
# MPB solved for frequency_7(1.64393,0,0) = 1.75 after 1 iters
# MPB solved for frequency_7(1.64393,0,0) = 1.75 after 1 iters
# Dominant planewave for band 7: (1.643928,-0.600000,0.000000)
# MPB solved for frequency_7(1.68828,0,0) = 1.79173 after 31 iters
# MPB solved for frequency_7(1.68821,0,0) = 1.79167 after 1 iters
# MPB solved for frequency_7(1.68821,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 7: (1.688215,-0.600000,0.000000)
# MPB solved for frequency_7(1.73243,0,0) = 1.83339 after 32 iters
# MPB solved for frequency_7(1.73237,0,0) = 1.83333 after 1 iters
# MPB solved for frequency_7(1.73237,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 7: (1.732372,-0.600000,0.000000)
# MPB solved for frequency_7(1.77647,0,0) = 1.87506 after 36 iters
# MPB solved for frequency_7(1.77641,0,0) = 1.875 after 1 iters
# MPB solved for frequency_7(1.77641,0,0) = 1.875 after 1 iters
# Dominant planewave for band 7: (1.776408,-0.600000,0.000000)
# MPB solved for frequency_7(1.82039,0,0) = 1.91672 after 33 iters
# MPB solved for frequency_7(1.82033,0,0) = 1.91667 after 1 iters
# MPB solved for frequency_7(1.82033,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 7: (1.820333,-0.600000,0.000000)
# MPB solved for frequency_7(1.8642,0,0) = 1.95838 after 34 iters
# MPB solved for frequency_7(1.86415,0,0) = 1.95833 after 1 iters
# MPB solved for frequency_7(1.86415,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 7: (1.864154,-0.600000,0.000000)
# MPB solved for frequency_7(1.90793,0,0) = 2.00004 after 35 iters
# MPB solved for frequency_7(1.90788,0,0) = 2 after 1 iters
# MPB solved for frequency_7(1.90788,0,0) = 2 after 1 iters
# Dominant planewave for band 7: (1.907878,-0.600000,0.000000)
# MPB solved for frequency_7(1.95156,0,0) = 2.04171 after 35 iters
# MPB solved for frequency_7(1.95151,0,0) = 2.04167 after 1 iters
# MPB solved for frequency_7(1.95151,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 7: (1.951513,-0.600000,0.000000)
# MPB solved for frequency_7(1.9951,0,0) = 2.08337 after 39 iters
# MPB solved for frequency_7(1.99506,0,0) = 2.08333 after 1 iters
# MPB solved for frequency_7(1.99506,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 7: (1.995063,-0.600000,0.000000)
# MPB solved for frequency_7(2.03857,0,0) = 2.12504 after 36 iters
# MPB solved for frequency_7(2.03854,0,0) = 2.125 after 1 iters
# MPB solved for frequency_7(2.03854,0,0) = 2.125 after 1 iters
# Dominant planewave for band 7: (2.038535,-0.600000,0.000000)
# MPB solved for frequency_7(2.08197,0,0) = 2.1667 after 37 iters
# MPB solved for frequency_7(2.08193,0,0) = 2.16667 after 1 iters
# MPB solved for frequency_7(2.08193,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 7: (2.081933,-0.600000,0.000000)
# MPB solved for frequency_7(2.1253,0,0) = 2.20837 after 38 iters
# MPB solved for frequency_7(2.12526,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 7: (2.125261,-0.600000,0.000000)
# MPB solved for frequency_7(2.16856,0,0) = 2.25003 after 38 iters
# MPB solved for frequency_7(2.16852,0,0) = 2.25 after 1 iters
# Dominant planewave for band 7: (2.168525,-0.600000,0.000000)
# MPB solved for frequency_7(2.21176,0,0) = 2.2917 after 39 iters
# MPB solved for frequency_7(2.21173,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 7: (2.211727,-0.600000,0.000000)
# MPB solved for frequency_7(2.2549,0,0) = 2.33336 after 40 iters
# MPB solved for frequency_7(2.25487,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 7: (2.254871,-0.600000,0.000000)
# MPB solved for frequency_7(2.29799,0,0) = 2.37503 after 45 iters
# MPB solved for frequency_7(2.29796,0,0) = 2.375 after 1 iters
# Dominant planewave for band 7: (2.297961,-0.600000,0.000000)
# MPB solved for frequency_7(2.34102,0,0) = 2.41669 after 45 iters
# MPB solved for frequency_7(2.341,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 7: (2.340999,-0.600000,0.000000)
# MPB solved for frequency_7(2.38401,0,0) = 2.45836 after 41 iters
# MPB solved for frequency_7(2.38399,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 7: (2.383989,-0.600000,0.000000)
# MPB solved for frequency_7(2.42695,0,0) = 2.50002 after 45 iters
# MPB solved for frequency_7(2.42693,0,0) = 2.5 after 1 iters
# Dominant planewave for band 7: (2.426932,-0.600000,0.000000)
# MPB solved for frequency_8(2.42695,0,0) = 2.52589 after 43 iters
# MPB solved for frequency_8(1.53271,0,0) = 1.68499 after 2 iters
# MPB solved for frequency_8(1.51256,0,0) = 1.66669 after 1 iters
# MPB solved for frequency_8(1.51254,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_8(1.51254,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 8: (1.512540,-0.700000,0.000000)
# MPB solved for frequency_8(1.55845,0,0) = 1.70844 after 28 iters
# MPB solved for frequency_8(1.55833,0,0) = 1.70833 after 1 iters
# MPB solved for frequency_8(1.55833,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 8: (1.558333,-0.700000,0.000000)
# MPB solved for frequency_8(1.60401,0,0) = 1.7501 after 36 iters
# MPB solved for frequency_8(1.6039,0,0) = 1.75 after 1 iters
# MPB solved for frequency_8(1.6039,0,0) = 1.75 after 1 iters
# Dominant planewave for band 8: (1.603901,-0.700000,0.000000)
# MPB solved for frequency_8(1.64936,0,0) = 1.79176 after 32 iters
# MPB solved for frequency_8(1.64926,0,0) = 1.79167 after 1 iters
# MPB solved for frequency_8(1.64926,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 8: (1.649263,-0.700000,0.000000)
# MPB solved for frequency_8(1.69453,0,0) = 1.83342 after 32 iters
# MPB solved for frequency_8(1.69444,0,0) = 1.83333 after 1 iters
# MPB solved for frequency_8(1.69444,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 8: (1.694435,-0.700000,0.000000)
# MPB solved for frequency_8(1.73952,0,0) = 1.87508 after 32 iters
# MPB solved for frequency_8(1.73943,0,0) = 1.875 after 1 iters
# MPB solved for frequency_8(1.73943,0,0) = 1.875 after 1 iters
# Dominant planewave for band 8: (1.739432,-0.700000,0.000000)
# MPB solved for frequency_8(1.78435,0,0) = 1.91674 after 34 iters
# MPB solved for frequency_8(1.78427,0,0) = 1.91667 after 1 iters
# MPB solved for frequency_8(1.78427,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 8: (1.784268,-0.700000,0.000000)
# MPB solved for frequency_8(1.82903,0,0) = 1.9584 after 32 iters
# MPB solved for frequency_8(1.82895,0,0) = 1.95833 after 1 iters
# MPB solved for frequency_8(1.82895,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 8: (1.828953,-0.700000,0.000000)
# MPB solved for frequency_8(1.87357,0,0) = 2.00006 after 33 iters
# MPB solved for frequency_8(1.8735,0,0) = 2 after 1 iters
# MPB solved for frequency_8(1.8735,0,0) = 2 after 1 iters
# Dominant planewave for band 8: (1.873499,-0.700000,0.000000)
# MPB solved for frequency_8(1.91798,0,0) = 2.04173 after 36 iters
# MPB solved for frequency_8(1.91792,0,0) = 2.04167 after 1 iters
# MPB solved for frequency_8(1.91792,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 8: (1.917916,-0.700000,0.000000)
# MPB solved for frequency_8(1.96227,0,0) = 2.08339 after 33 iters
# MPB solved for frequency_8(1.96221,0,0) = 2.08333 after 1 iters
# MPB solved for frequency_8(1.96221,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 8: (1.962212,-0.700000,0.000000)
# MPB solved for frequency_8(2.00645,0,0) = 2.12505 after 34 iters
# MPB solved for frequency_8(2.0064,0,0) = 2.125 after 1 iters
# MPB solved for frequency_8(2.0064,0,0) = 2.125 after 1 iters
# Dominant planewave for band 8: (2.006396,-0.700000,0.000000)
# MPB solved for frequency_8(2.05053,0,0) = 2.16672 after 35 iters
# MPB solved for frequency_8(2.05047,0,0) = 2.16667 after 1 iters
# MPB solved for frequency_8(2.05047,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 8: (2.050474,-0.700000,0.000000)
# MPB solved for frequency_8(2.0945,0,0) = 2.20838 after 35 iters
# MPB solved for frequency_8(2.09445,0,0) = 2.20833 after 1 iters
# MPB solved for frequency_8(2.09445,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 8: (2.094454,-0.700000,0.000000)
# MPB solved for frequency_8(2.13839,0,0) = 2.25004 after 39 iters
# MPB solved for frequency_8(2.13834,0,0) = 2.25 after 1 iters
# MPB solved for frequency_8(2.13834,0,0) = 2.25 after 1 iters
# Dominant planewave for band 8: (2.138340,-0.700000,0.000000)
# MPB solved for frequency_8(2.18218,0,0) = 2.29171 after 36 iters
# MPB solved for frequency_8(2.18214,0,0) = 2.29167 after 1 iters
# MPB solved for frequency_8(2.18214,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 8: (2.182140,-0.700000,0.000000)
# MPB solved for frequency_8(2.2259,0,0) = 2.33337 after 37 iters
# MPB solved for frequency_8(2.22586,0,0) = 2.33333 after 1 iters
# MPB solved for frequency_8(2.22586,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 8: (2.225858,-0.700000,0.000000)
# MPB solved for frequency_8(2.26954,0,0) = 2.37504 after 37 iters
# MPB solved for frequency_8(2.2695,0,0) = 2.375 after 1 iters
# MPB solved for frequency_8(2.2695,0,0) = 2.375 after 1 iters
# Dominant planewave for band 8: (2.269499,-0.700000,0.000000)
# MPB solved for frequency_8(2.3131,0,0) = 2.4167 after 39 iters
# MPB solved for frequency_8(2.31307,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 8: (2.313067,-0.700000,0.000000)
# MPB solved for frequency_8(2.3566,0,0) = 2.45837 after 39 iters
# MPB solved for frequency_8(2.35657,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 8: (2.356566,-0.700000,0.000000)
# MPB solved for frequency_8(2.40003,0,0) = 2.50003 after 39 iters
# MPB solved for frequency_8(2.4,0,0) = 2.5 after 1 iters
# Dominant planewave for band 8: (2.400000,-0.700000,0.000000)
# MPB solved for frequency_9(2.40003,0,0) = 2.52985 after 43 iters
# MPB solved for frequency_9(1.49016,0,0) = 1.69132 after 1 iters
# MPB solved for frequency_9(1.46217,0,0) = 1.66672 after 1 iters
# MPB solved for frequency_9(1.46211,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_9(1.46211,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 9: (1.462114,-0.800000,0.000000)
# MPB solved for frequency_9(1.50961,0,0) = 1.70849 after 30 iters
# MPB solved for frequency_9(1.50944,0,0) = 1.70833 after 1 iters
# MPB solved for frequency_9(1.50944,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 9: (1.509438,-0.800000,0.000000)
# MPB solved for frequency_9(1.55659,0,0) = 1.75014 after 31 iters
# MPB solved for frequency_9(1.55644,0,0) = 1.75 after 1 iters
# MPB solved for frequency_9(1.55644,0,0) = 1.75 after 1 iters
# Dominant planewave for band 9: (1.556438,-0.800000,0.000000)
# MPB solved for frequency_9(1.60329,0,0) = 1.79179 after 32 iters
# MPB solved for frequency_9(1.60314,0,0) = 1.79167 after 1 iters
# MPB solved for frequency_9(1.60314,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 9: (1.603144,-0.800000,0.000000)
# MPB solved for frequency_9(1.64971,0,0) = 1.83345 after 32 iters
# MPB solved for frequency_9(1.64958,0,0) = 1.83333 after 1 iters
# MPB solved for frequency_9(1.64958,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 9: (1.649579,-0.800000,0.000000)
# MPB solved for frequency_9(1.69589,0,0) = 1.87511 after 32 iters
# MPB solved for frequency_9(1.69577,0,0) = 1.875 after 1 iters
# MPB solved for frequency_9(1.69577,0,0) = 1.875 after 1 iters
# Dominant planewave for band 9: (1.695767,-0.800000,0.000000)
# MPB solved for frequency_9(1.74184,0,0) = 1.91677 after 33 iters
# MPB solved for frequency_9(1.74173,0,0) = 1.91667 after 1 iters
# MPB solved for frequency_9(1.74173,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 9: (1.741726,-0.800000,0.000000)
# MPB solved for frequency_9(1.78758,0,0) = 1.95843 after 34 iters
# MPB solved for frequency_9(1.78748,0,0) = 1.95833 after 1 iters
# MPB solved for frequency_9(1.78748,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 9: (1.787476,-0.800000,0.000000)
# MPB solved for frequency_9(1.83313,0,0) = 2.00009 after 34 iters
# MPB solved for frequency_9(1.83303,0,0) = 2 after 1 iters
# MPB solved for frequency_9(1.83303,0,0) = 2 after 1 iters
# Dominant planewave for band 9: (1.833030,-0.800000,0.000000)
# MPB solved for frequency_9(1.87849,0,0) = 2.04175 after 35 iters
# MPB solved for frequency_9(1.8784,0,0) = 2.04167 after 1 iters
# MPB solved for frequency_9(1.8784,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 9: (1.878404,-0.800000,0.000000)
# MPB solved for frequency_9(1.92369,0,0) = 2.08341 after 36 iters
# MPB solved for frequency_9(1.92361,0,0) = 2.08333 after 1 iters
# MPB solved for frequency_9(1.92361,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 9: (1.923611,-0.800000,0.000000)
# MPB solved for frequency_9(1.96874,0,0) = 2.12507 after 37 iters
# MPB solved for frequency_9(1.96866,0,0) = 2.125 after 1 iters
# MPB solved for frequency_9(1.96866,0,0) = 2.125 after 1 iters
# Dominant planewave for band 9: (1.968661,-0.800000,0.000000)
# MPB solved for frequency_9(2.01364,0,0) = 2.16673 after 38 iters
# MPB solved for frequency_9(2.01357,0,0) = 2.16667 after 1 iters
# MPB solved for frequency_9(2.01357,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 9: (2.013565,-0.800000,0.000000)
# MPB solved for frequency_9(2.0584,0,0) = 2.2084 after 38 iters
# MPB solved for frequency_9(2.05833,0,0) = 2.20833 after 1 iters
# MPB solved for frequency_9(2.05833,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 9: (2.058333,-0.800000,0.000000)
# MPB solved for frequency_9(2.10304,0,0) = 2.25006 after 38 iters
# MPB solved for frequency_9(2.10297,0,0) = 2.25 after 1 iters
# MPB solved for frequency_9(2.10297,0,0) = 2.25 after 1 iters
# Dominant planewave for band 9: (2.102974,-0.800000,0.000000)
# MPB solved for frequency_9(2.14755,0,0) = 2.29172 after 39 iters
# MPB solved for frequency_9(2.1475,0,0) = 2.29167 after 1 iters
# MPB solved for frequency_9(2.1475,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 9: (2.147495,-0.800000,0.000000)
# MPB solved for frequency_9(2.19196,0,0) = 2.33338 after 40 iters
# MPB solved for frequency_9(2.1919,0,0) = 2.33333 after 1 iters
# MPB solved for frequency_9(2.1919,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 9: (2.191904,-0.800000,0.000000)
# MPB solved for frequency_9(2.23626,0,0) = 2.37505 after 40 iters
# MPB solved for frequency_9(2.23621,0,0) = 2.375 after 1 iters
# MPB solved for frequency_9(2.23621,0,0) = 2.375 after 1 iters
# Dominant planewave for band 9: (2.236208,-0.800000,0.000000)
# MPB solved for frequency_9(2.28046,0,0) = 2.41671 after 42 iters
# MPB solved for frequency_9(2.28041,0,0) = 2.41667 after 1 iters
# MPB solved for frequency_9(2.28041,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 9: (2.280412,-0.800000,0.000000)
# MPB solved for frequency_9(2.32457,0,0) = 2.45838 after 42 iters
# MPB solved for frequency_9(2.32452,0,0) = 2.45833 after 1 iters
# MPB solved for frequency_9(2.32452,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 9: (2.324522,-0.800000,0.000000)
# MPB solved for frequency_9(2.36859,0,0) = 2.50004 after 42 iters
# MPB solved for frequency_9(2.36854,0,0) = 2.5 after 1 iters
# MPB solved for frequency_9(2.36854,0,0) = 2.5 after 1 iters
# Dominant planewave for band 9: (2.368544,-0.800000,0.000000)
# MPB solved for frequency_10(2.36859,0,0) = 2.53381 after 44 iters
# MPB solved for frequency_10(1.44095,0,0) = 1.69892 after 2 iters
# MPB solved for frequency_10(1.40292,0,0) = 1.66679 after 1 iters
# MPB solved for frequency_10(1.40278,0,0) = 1.66667 after 1 iters
# MPB solved for frequency_10(1.40278,0,0) = 1.66667 after 1 iters
# Dominant planewave for band 10: (1.402775,-0.900000,0.000000)
# MPB solved for frequency_10(1.45228,0,0) = 1.70854 after 33 iters
# MPB solved for frequency_10(1.45203,0,0) = 1.70833 after 1 iters
# MPB solved for frequency_10(1.45203,0,0) = 1.70833 after 1 iters
# Dominant planewave for band 10: (1.452034,-0.900000,0.000000)
# MPB solved for frequency_10(1.50106,0,0) = 1.75019 after 33 iters
# MPB solved for frequency_10(1.50083,0,0) = 1.75 after 1 iters
# MPB solved for frequency_10(1.50083,0,0) = 1.75 after 1 iters
# Dominant planewave for band 10: (1.500833,-0.900000,0.000000)
# MPB solved for frequency_10(1.54942,0,0) = 1.79184 after 34 iters
# MPB solved for frequency_10(1.54922,0,0) = 1.79167 after 1 iters
# MPB solved for frequency_10(1.54922,0,0) = 1.79167 after 1 iters
# Dominant planewave for band 10: (1.549216,-0.900000,0.000000)
# MPB solved for frequency_10(1.5974,0,0) = 1.83349 after 35 iters
# MPB solved for frequency_10(1.59722,0,0) = 1.83333 after 1 iters
# MPB solved for frequency_10(1.59722,0,0) = 1.83333 after 1 iters
# Dominant planewave for band 10: (1.597220,-0.900000,0.000000)
# MPB solved for frequency_10(1.64505,0,0) = 1.87515 after 34 iters
# MPB solved for frequency_10(1.64488,0,0) = 1.875 after 1 iters
# MPB solved for frequency_10(1.64488,0,0) = 1.875 after 1 iters
# Dominant planewave for band 10: (1.644878,-0.900000,0.000000)
# MPB solved for frequency_10(1.69237,0,0) = 1.9168 after 36 iters
# MPB solved for frequency_10(1.69222,0,0) = 1.91667 after 1 iters
# MPB solved for frequency_10(1.69222,0,0) = 1.91667 after 1 iters
# Dominant planewave for band 10: (1.692221,-0.900000,0.000000)
# MPB solved for frequency_10(1.73941,0,0) = 1.95846 after 35 iters
# MPB solved for frequency_10(1.73927,0,0) = 1.95833 after 1 iters
# MPB solved for frequency_10(1.73927,0,0) = 1.95833 after 1 iters
# Dominant planewave for band 10: (1.739273,-0.900000,0.000000)
# MPB solved for frequency_10(1.78619,0,0) = 2.00012 after 37 iters
# MPB solved for frequency_10(1.78606,0,0) = 2 after 1 iters
# MPB solved for frequency_10(1.78606,0,0) = 2 after 1 iters
# Dominant planewave for band 10: (1.786057,-0.900000,0.000000)
# MPB solved for frequency_10(1.83271,0,0) = 2.04177 after 37 iters
# MPB solved for frequency_10(1.83259,0,0) = 2.04167 after 1 iters
# MPB solved for frequency_10(1.83259,0,0) = 2.04167 after 1 iters
# Dominant planewave for band 10: (1.832595,-0.900000,0.000000)
# MPB solved for frequency_10(1.87901,0,0) = 2.08343 after 38 iters
# MPB solved for frequency_10(1.8789,0,0) = 2.08333 after 1 iters
# MPB solved for frequency_10(1.8789,0,0) = 2.08333 after 1 iters
# Dominant planewave for band 10: (1.878903,-0.900000,0.000000)
# MPB solved for frequency_10(1.9251,0,0) = 2.12509 after 37 iters
# MPB solved for frequency_10(1.925,0,0) = 2.125 after 1 iters
# MPB solved for frequency_10(1.925,0,0) = 2.125 after 1 iters
# Dominant planewave for band 10: (1.925000,-0.900000,0.000000)
# MPB solved for frequency_10(1.971,0,0) = 2.16675 after 38 iters
# MPB solved for frequency_10(1.9709,0,0) = 2.16667 after 1 iters
# MPB solved for frequency_10(1.9709,0,0) = 2.16667 after 1 iters
# Dominant planewave for band 10: (1.970899,-0.900000,0.000000)
# MPB solved for frequency_10(2.0167,0,0) = 2.20842 after 38 iters
# MPB solved for frequency_10(2.01662,0,0) = 2.20833 after 1 iters
# MPB solved for frequency_10(2.01662,0,0) = 2.20833 after 1 iters
# Dominant planewave for band 10: (2.016615,-0.900000,0.000000)
# MPB solved for frequency_10(2.06224,0,0) = 2.25008 after 41 iters
# MPB solved for frequency_10(2.06216,0,0) = 2.25 after 1 iters
# MPB solved for frequency_10(2.06216,0,0) = 2.25 after 1 iters
# Dominant planewave for band 10: (2.062159,-0.900000,0.000000)
# MPB solved for frequency_10(2.10762,0,0) = 2.29174 after 41 iters
# MPB solved for frequency_10(2.10754,0,0) = 2.29167 after 1 iters
# MPB solved for frequency_10(2.10754,0,0) = 2.29167 after 1 iters
# Dominant planewave for band 10: (2.107543,-0.900000,0.000000)
# MPB solved for frequency_10(2.15285,0,0) = 2.3334 after 41 iters
# MPB solved for frequency_10(2.15278,0,0) = 2.33333 after 1 iters
# MPB solved for frequency_10(2.15278,0,0) = 2.33333 after 1 iters
# Dominant planewave for band 10: (2.152776,-0.900000,0.000000)
# MPB solved for frequency_10(2.19794,0,0) = 2.37506 after 43 iters
# MPB solved for frequency_10(2.19787,0,0) = 2.375 after 1 iters
# MPB solved for frequency_10(2.19787,0,0) = 2.375 after 1 iters
# Dominant planewave for band 10: (2.197868,-0.900000,0.000000)
# MPB solved for frequency_10(2.24289,0,0) = 2.41673 after 43 iters
# MPB solved for frequency_10(2.24283,0,0) = 2.41667 after 1 iters
# MPB solved for frequency_10(2.24283,0,0) = 2.41667 after 1 iters
# Dominant planewave for band 10: (2.242828,-0.900000,0.000000)
# MPB solved for frequency_10(2.28772,0,0) = 2.45839 after 42 iters
# MPB solved for frequency_10(2.28766,0,0) = 2.45833 after 1 iters
# MPB solved for frequency_10(2.28766,0,0) = 2.45833 after 1 iters
# Dominant planewave for band 10: (2.287663,-0.900000,0.000000)
# MPB solved for frequency_10(2.33244,0,0) = 2.50005 after 43 iters
# MPB solved for frequency_10(2.33238,0,0) = 2.5 after 1 iters
# MPB solved for frequency_10(2.33238,0,0) = 2.5 after 1 iters
# Dominant planewave for band 10: (2.332381,-0.900000,0.000000)

# %% [markdown]
# Note the use of the keyword parameter argument `eig_parity=mp.ODD_Z+mp.EVEN_Y` in the call to `get_eigenmode_coefficients`. This is important for specifying **non-degenerate** modes in MPB since the `k_point` is (0,0,0). `ODD_Z` is for modes with E<sub>z</sub> polarization. `EVEN_Y` is necessary since each diffraction order which is based on a given k<sub>x</sub> consists of *two* modes: one going in the +y direction and the other in the -y direction. `EVEN_Y` forces MPB to compute only the +k<sub>y</sub> + -k<sub>y</sub> (cosine) mode. As a result, the total transmittance must be halved in this case to obtain the transmittance for the individual +k<sub>y</sub> or -k<sub>y</sub> mode. For `ODD_Y`, MPB will compute the +k<sub>y</sub> - -k<sub>y</sub> (sine) mode but this will have zero power because the source is even. If the $y$ parity is left out, MPB will return a random superposition of the cosine and sine modes. Alternatively, in this example an input planewave with H<sub>z</sub> instead of E<sub>z</sub> polarization can be used which requires `eig_parity=mp.EVEN_Z+mp.ODD_Y` as well as an odd mirror symmetry plane in *y*. Finally, note the use of `add_flux` instead of `add_mode_monitor` when using symmetries.
#
# The diffraction spectrum is then plotted and shown in the figure below.

# %%
plt.figure(dpi=200)
plt.pcolormesh(
    np.reshape(mode_wvl, (nmode, nfreq)),
    np.reshape(mode_angle, (nmode, nfreq)),
    np.reshape(mode_tran, (nmode, nfreq)),
    #cmap="Blues",
    #shading="flat",
    vmin=0,
    vmax=tran_max,
)
plt.axis([min(mode_wvl), max(mode_wvl), min(mode_angle), max(mode_angle)])
plt.xlabel("wavelength (μm)")
plt.ylabel("diffraction angle (degrees)")
plt.xticks([t for t in np.linspace(wvl_min, wvl_max, 3)])
plt.yticks([t for t in range(0, 35, 5)])
plt.title("transmittance of diffraction orders")
cbar = plt.colorbar()
cbar.set_ticks([t for t in np.arange(0, tran_max + 0.1, 0.1)])
cbar.set_ticklabels(["{:.1f}".format(t) for t in np.arange(0, tran_max + 0.1, 0.1)])
# Out:
# /tmp/ipykernel_350780/3260786392.py:2: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(

# %% [markdown]
# Each diffraction order corresponds to a single angle. In the figure, this angle is represented by the *lower* boundary of each labeled region. For example, the $m$=0 order has a diffraction angle of 0° at all wavelengths. The representation of the diffraction orders as finite angular regions is an artifact of matplotlib's [pcolormesh](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pcolormesh.html) routine. Note that only the positive diffraction orders are shown as these are equivalent to the negative orders due to the symmetry of the source and the structure. The transmittance of each diffraction order should ideally be a constant for all wavelengths. The slight wavelength dependence shown in the figure is due to numerical discretization which can be mitigated by increasing the resolution.
#
# The diffraction orders/modes are a finite set of propagating planewaves. The wavevector $k_x$ of these modes can be computed analytically: for a frequency of $ω$ (in $c$=1 units), these propagating modes are the **real** solutions of sqrt(ω²n²-($k_y$+2π$m$/$Λ$)²) where $m$ is the diffraction order (an integer), $Λ$ is the periodicity of the grating, and $n$ is the refractive index of the propagating medium. In this example, $n$=1, $k_y$=0, and $Λ$=10 μm. Thus, at a wavelength of 0.5 μm there are a total of 20 diffraction orders of which we only computed the first 10. The wavevector $k_x$ is used to compute the angle of the diffraction order as cos<sup>-1</sup>($k_x$/($ωn$)). Evanescent modes, those with an imaginary k<sub>x</sub>, exist for |$m$|>20 but these modes carry no power. Note that currently Meep does not compute the number of propagating modes for you. If the mode number passed to `get_eigenmode_coefficients` is larger than the number of propagating modes at a given frequency/wavelength, MPB's Newton solver will fail to converge and will return zero for the mode\ coefficient. It is therefore a good idea to know beforehand the number of propagating modes.
